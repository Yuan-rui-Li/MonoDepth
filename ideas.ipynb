# %%
from tests.test_datasets.test_transform import test_albu_channel_order
import albumentations as A
from PIL import Image
import numpy as np
import cv2
image = cv2.imread('000006.jpg',cv2.IMREAD_UNCHANGED)
image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
transform= A.Compose([
    A.RandomCrop(width=540, height=720,p=1),
    A.RandomBrightnessContrast(brightness_limit = 0.3, contrast_limit= 0.3, p=0.3),
    A.RandomGamma(gamma_limit=(50,200),p=0.3),
    A.HueSaturationValue(hue_shift_limit=30,sat_shift_limit=30,val_shift_limit=30,p=0.3),
    A.RGBShift(r_shift_limit=20,g_shift_limit=20,b_shift_limit=30,p=0.3)
])
#transform = A.RGBShift(20,20,50,p=0.8)
augmented_image = transform(image=image)['image']
#(B, G, R) = cv2.split(data['img'])
Image.fromarray(augmented_image)
#image = Image.fromarray(cv2.merge([R, G, B]))

# %%
import albumentations as A
from PIL import Image
import numpy as np
import cv2
image = cv2.imread('/root/autodl-tmp/ZED/images/test/000000.jpg',cv2.IMREAD_UNCHANGED)
image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
factor = 1.06976
transform= A.Compose([
    A.Resize(height=672,width=1197),
    A.CenterCrop(height=656,width=1184)

])
augmented_image = transform(image=image)['image']
Image.fromarray(augmented_image)
# Out:
# <PIL.Image.Image image mode=RGB size=1197x672>

# %%
def get_nInt(number):
    n=int(number)
    return len(str(n))
get_nInt(12589.33)
# Out:
# 5

# %%
import math
tick_interval = [1,5,10,20,50,100,200,500,1000,2000,5000,10000]
max_v =18126.465
nInt = get_nInt(max_v)

base_v=min(tick_interval , key=lambda x: abs(x -  (max_v//50)))
nBase = int(max_v//base_v)

ticks = [int(i**1.67)*base_v for i in range(1,int(nBase**0.6)+1, 1)]
ticks
# Out:
# [500, 1500, 3000, 5000, 7000, 9500, 12500, 16000]

# %%
for i in range(0,int(12**0.75)+1):
               print(i)
# Out:
# 0
# 1
# 2
# 3
# 4
# 5
# 6

# %%
import os
img_file = '1/2/3.jpg'
os.path.basename(img_file).split('.')[0]
os.path.split(img_file)[0]
# Out:
# '1/2'
